# %% [markdown]
# # Ecommerce Purchases Exercise Overview
#
# Hi Guys,<br>
# After a crash course on pandas for data analysis, its time to do some practice!!!<br>
# Because of privacy issues, I have created a fake dataset here with 30K entries. <br>
# The situation is, customers are providing some personal information while purchasing stuff on-line or in-store. For some reasons, your client wants to know the answer to some of his questions from the dataset, let's try to help him!.<br>
#
# *Feel free to consult the solutions if needed. Please note, the tasks given in the exercises, can be solved in different ways. Try your best answer and compare with the solutions.* <br>
# &#9758; The dataset is provided in the course downloads.

# %% [markdown]
# **1. Import Pandas and Read the csv file.**

# %%
# Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing pandas and reading the CSV data
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ML&DS/Pandas/Pandas_Assignment/Cust_Purch_FakeData.csv')

# %% [markdown]
# **2. Its good idea to see how the data look like, display first 5 rows of your data-set.**

# %%
# Displaying first 5 rows of dataset
df.head()
# Out:
#   prefix    first       last              email  gender  age  \
# 0    Dr.      Ray     Morton    sebvajom@kol.km    Male   38
# 1   Miss  Claudia  Rodriquez      acu@jatsot.ug  Female   51
# 2   Miss    Harry      Meyer          zuz@lo.wf  Female   51
# 3   Miss    Edith    Gilbert  hansohsi@jupec.md  Female   55
# 4    Dr.     Lura     Murphy     webediti@je.st  Female   20
#
#                         company              profession           phone  \
# 0                Medtronic Inc.        Health Therapist  (987) 619-2695
# 1  Ames Department Stores, Inc.        Health Therapist  (356) 736-7352
# 2                     CSX Corp.     Political Scientist  (539) 246-1806
# 3        Murphy Oil Corporation  Transportation Manager  (984) 962-7494
# 4                  PETsMART Inc            Statistician  (902) 568-9748
#
#     postal province             cc_no   cc_exp                    cc_type  \
# 0  B6V 3W3       MB  5020000000000230  05/2018                       Solo
# 1  G7M 5F3       SK  5020000000000230  07/2028                       Visa
# 2  A0Z 6P9       NS  6300000000000000  02/2023                     Switch
# 3  P9I 9H3       YT  3530000000000000  02/2028                    Maestro
# 4  S1A 6K0       ON  4030000000000000  10/2025  Diners Club International
#
#    price(CAD) fav_color              ip    weekday ampm        date
# 0        8.36      Blue    126.23.139.2     Sunday   pm  04/05/1930
# 1       68.31     Black  106.198.76.211    Tuesday   am  12/20/1926
# 2       34.65     Black  186.150.187.29  Wednesday   pm  08/20/1931
# 3       64.59     White   80.140.57.161   Saturday   am  06/18/2001
# 4       20.83    Yellow   211.103.43.41     Friday   pm  06/14/2045

# %% [markdown]
# **3. How many entries your data have?
# Can you tell the no. of columns in your data?**

# %%
# Printing dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   prefix      30000 non-null  object
#  1   first       30000 non-null  object
#  2   last        30000 non-null  object
#  3   email       30000 non-null  object
#  4   gender      30000 non-null  object
#  5   age         30000 non-null  int64
#  6   company     30000 non-null  object
#  7   profession  30000 non-null  object
#  8   phone       30000 non-null  object
#  9   postal      30000 non-null  object
#  10  province    30000 non-null  object
#  11  cc_no       30000 non-null  int64
#  12  cc_exp      30000 non-null  object
#  13  cc_type     30000 non-null  object
#  14  price(CAD)  30000 non-null  float64
#  15  fav_color   30000 non-null  object
#  16  ip          30000 non-null  object
#  17  weekday     30000 non-null  object
#  18  ampm        30000 non-null  object
#  19  date        30000 non-null  object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 4.6+ MB

# %% [markdown]
# **4. What are the max and min ages of your customer? Can you find mean of your customer?**

# %%
# Calculating Max, Min and Mean age of customers
print(f'Max. age of the customer is: {df["age"].max()}')
print(f'Min. age of the customer is: {df["age"].min()}')
print(f'Mean age of the customer is: {df["age"].mean():.2f}')
# Out:
# Max. age of the customer is: 65
# Min. age of the customer is: 18
# Mean age of the customer is: 41.55

# %% [markdown]
# **5. What are the three most common customer's names?**<br>
# &#9989; [<code>**value_counts()**</code>](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) returns object containing counts of unique values. The resulting object will be in descending order so that the first element is the most frequently-occurring element. Excludes NA values by default.

# %%
# Displaying the three most common customer's name
df['first'].value_counts().head(3)
# Out:
# first
# Willie     130
# Francis    124
# Eula        86
# Name: count, dtype: int64

# %% [markdown]
# **6. Two customers have the same phone number, can you find those customers**?

# %%
# Finding what phone number is twice!
df['phone'].value_counts().head(1)
# Out:
# phone
# (263) 382-8004    2
# Name: count, dtype: int64

# %%
# Now we know the phone number, let's find out the other stuff!
df[df['phone']=='(263) 382-8004']
# Out:
#    prefix  first   last                email  gender  age            company  \
# 15   Mrs.  Lilly  Tyler      kofadu@itohi.tf  Female   38          CSX Corp.
# 16   Mrs.  Peter   Cain  megkosig@anazeor.gn    Male   27  Campbell Soup Co.
#
#              profession           phone   postal province             cc_no  \
# 15  Structural Engineer  (263) 382-8004  V7K 1E3       ON    30000000000000
# 16   Insurance Adjuster  (263) 382-8004  E8T 2B4       YT  3530000000000000
#
#      cc_exp                    cc_type  price(CAD) fav_color              ip  \
# 15  11/2022  Diners Club Carte Blanche        9.61    Yellow   74.124.37.227
# 16  03/2024                       Solo       13.74     Black  25.207.141.135
#
#      weekday ampm        date
# 15  Saturday   am  03/30/1985
# 16   Tuesday   am  08/05/1950

# %% [markdown]
# **7. How many customers have profession "Structural Engineer"?**

# %%
# Counting the total number of customers who are 'Structural Engineer'
df[df['profession']=='Structural Engineer'].count()
# Out:
# prefix        87
# first         87
# last          87
# email         87
# gender        87
# age           87
# company       87
# profession    87
# phone         87
# postal        87
# province      87
# cc_no         87
# cc_exp        87
# cc_type       87
# price(CAD)    87
# fav_color     87
# ip            87
# weekday       87
# ampm          87
# date          87
# dtype: int64

# %%
df[(df['profession']=='Structural Engineer') & (df['gender']=='Male')]
# Out:
#       prefix      first       last                  email gender  age  \
# 628     Miss     Walter  Jefferson           lo@yahoo.com   Male   29
# 797      Dr.    Harriet     Foster   pegsooja@hotmail.com   Male   27
# 1650     Mr.     Dustin    Ballard     irikehah@yahoo.com   Male   60
# 1891     Dr.     Callie       Ball      obuevpo@yahoo.com   Male   64
# 2415     Dr.       Lina      Mason          feh@gmail.com   Male   39
# 3275     Dr.     Amanda     Morgan        okoje@gmail.com   Male   38
# 3315    Miss      Irene    Coleman           wu@gmail.com   Male   42
# 4545    Mrs.      Craig      Riley          zut@yahoo.com   Male   62
# 5361     Mr.     Lenora  Armstrong         miarita@ona.uy   Male   51
# 6377     Dr.  Charlotte       Bell      tuihaba@uhahan.nu   Male   21
# 7541     Mr.      Madge    Delgado            ba@ilbuf.ao   Male   65
# 8425    Mrs.      Keith      Cohen  posmatdu@mojdaliba.in   Male   39
# 3275    50.225.168.164     Monday   am  05/18/2023
# 3315    216.110.164.55     Monday   am  07/24/1986
# 4545     90.104.50.229  Wednesday   am  01/15/1978
# 5361    110.124.14.193  Wednesday   am  10/07/1916
# 6377    243.53.247.148   Saturday   pm  05/08/1923
# 7541     226.75.235.79   Saturday   am  04/18/1937
# 8425     238.44.116.64     Sunday   am  04/09/1910
# 9376    83.228.100.179    Tuesday   pm  06/02/2025
# 9789      247.127.27.4  Wednesday   am  06/14/1916
# 12834   172.178.124.83   Saturday   pm  05/05/1983
# 12885     32.159.61.95     Friday   pm  04/27/2028
# 13002    218.189.82.83   Thursday   pm  10/09/2053
# 13047   244.236.99.225   Thursday   am  08/27/2039
# 13707    83.176.200.99     Friday   pm  11/10/1920
# 14803  232.215.203.101   Saturday   pm  07/08/1915
# 14985   239.158.92.166  Wednesday   am  01/15/2023
# 15183   188.42.232.119   Saturday   am  09/06/1972
# 16539  208.227.126.139   Thursday   am  04/08/2037
# 17301     16.59.213.35   Saturday   am  06/29/2064
# 17811   232.215.78.124     Sunday   pm  04/27/1975
# 17856   247.92.248.171  Wednesday   am  01/26/1900
# 18620    92.128.249.91    Tuesday   am  02/05/2051
# 20708    93.88.110.125     Sunday   pm  11/23/1936
# 21546   19.225.158.240     Friday   pm  07/21/1919
# 22592   150.103.88.238     Friday   am  02/28/1976
# 22698    118.62.254.46   Saturday   am  09/06/2033
# 23174     90.229.35.49    Tuesday   am  12/06/1917
# 23300  244.179.187.186     Friday   pm  07/14/1966
# 23466   81.240.226.151   Saturday   pm  07/01/2045
# 23982   149.85.211.135    Tuesday   pm  02/12/1960
# 24141    132.223.55.51     Sunday   pm  06/01/1969
# 24818   212.30.116.116    Tuesday   pm  01/02/2018
# 26687   180.116.15.226   Saturday   pm  04/08/1982
# 26862  150.110.249.234     Sunday   pm  07/24/1954
# 26964   206.14.196.199     Friday   am  12/01/1930
# 27115    33.78.158.122     Sunday   pm  06/26/1982
# 28059   32.176.199.208     Monday   am  12/22/2041
# 29111  202.207.232.184   Saturday   pm  06/14/1975

# %% [markdown]
# **8. How many male customers are 'Structural Engineer'?**

# %%
# Counting the total number of male customers who are 'Structural Engineer'
df[(df['profession']=='Structural Engineer') & (df['gender']=='Male')].count()
# Out:
# prefix        43
# first         43
# last          43
# email         43
# gender        43
# age           43
# company       43
# profession    43
# phone         43
# postal        43
# province      43
# cc_no         43
# cc_exp        43
# cc_type       43
# price(CAD)    43
# fav_color     43
# ip            43
# weekday       43
# ampm          43
# date          43
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    15147
# Male      14853
# Name: count, dtype: int64

# %%
df[(df['profession']=='Structural Engineer') & (df['gender']=='Female')].count()
# Out:
# prefix        44
# first         44
# last          44
# email         44
# gender        44
# age           44
# company       44
# profession    44
# phone         44
# postal        44
# province      44
# cc_no         44
# cc_exp        44
# cc_type       44
# price(CAD)    44
# fav_color     44
# ip            44
# weekday       44
# ampm          44
# date          44
# dtype: int64

# %% [markdown]
# **9. Find out the female Structural Engineers from province Alberta (AB)?**

# %%
# Displaying female Structural Engineers from province Alberta (AB)
df[(df['profession']=='Structural Engineer') & (df['gender']=='Female') & (df['province']=='AB')]
# Out:
#       prefix first      last              email  gender  age  \
# 8858     Dr.   Roy   Stanley  apiunvo@ehasom.ir  Female   39
# 9058     Mr.  Lora   Kennedy    dennap@rabac.se  Female   51
# 24736   Mrs.  Nell  Richards          dob@me.ki  Female   18
# 29865   Mrs.   Don  McDaniel        naf@zudu.bj  Female   37
#
#                               company           profession           phone  \
# 8858       Cincinnati Financial Corp.  Structural Engineer  (876) 758-2929
# 9058              BJ Services Company  Structural Engineer  (305) 786-6959
# 24736    Telephone & Data Systems Inc  Structural Engineer  (262) 681-5018
# 29865  Anadarko Petroleum Corporation  Structural Engineer  (238) 789-2825
#
#         postal province             cc_no   cc_exp  \
# 8858   N5A 6L2       AB  6300000000000000  02/2022
# 9058   N3R 4B7       AB   201000000000000  06/2019
# 24736  N3Y 3G2       AB   347000000000000  07/2028
# 29865  B4A 8Q9       AB  5610000000000000  12/2022
#
#                                   cc_type  price(CAD) fav_color  \
# 8858                         InstaPayment       31.86       Red
# 9058   Diners Club United States & Canada       53.29     Black
# 24736                    American Express       76.28      Blue
# 29865                          Mastercard       62.71      Blue
#
#                     ip    weekday ampm        date
# 8858    165.249.159.57     Sunday   pm  12/25/1903
# 9058    42.216.243.206   Thursday   pm  06/06/2028
# 24736     91.16.30.156  Wednesday   pm  07/14/1951
# 29865  162.233.117.142     Sunday   pm  11/03/1989

# %% [markdown]
# **10. What is the max, min and average spending?**

# %%
# Displaying max, min and average spending
print(f'Max. spending: {df["price(CAD)"].max()}')
print(f'Min. spending: {df["price(CAD)"].min()}')
print(f'Avg. spending: {df["price(CAD)"].mean():.2f}')
# Out:
# Max. spending: 100.0
# Min. spending: 0.0
# Avg. spending: 49.99

# %% [markdown]
# **11. Who did not spend anything? Company wants to send a deal to encourage the customer to buy stuff!**

# %%
# Displaying customers who didn't spend anything
df[df['price(CAD)']==0]
# Out:
#       prefix  first   last           email  gender  age              company  \
# 5320     Dr.  Bruce  Bryan  ru@pubuspuh.cl    Male   59  Wal-Mart Stores Inc
# 10597   Mrs.  Flora  Clark      wad@me.com  Female   27         MetLife Inc.
#
#                 profession           phone   postal province            cc_no  \
# 5320   Engineer Technician  (709) 446-8317  H6H 3Y0       NU  201000000000000
# 10597      Cruise Director  (775) 373-6590  B2U 8K6       NB   30100000000000
#
#         cc_exp                    cc_type  price(CAD) fav_color  \
# 5320   04/2024                   Bankcard         0.0     White
# 10597  05/2020  Diners Club Carte Blanche         0.0       Red
#
#                   ip    weekday ampm        date
# 5320     82.70.62.64  Wednesday   am  12/11/1900
# 10597  231.156.15.63   Thursday   pm  08/22/1904

# %% [markdown]
# **12. As a loyalty reward, company wants to send thanks coupon to those who spent 100CAD or more, please find out the customers?**

# %%
# Displaying customers who spent 100 CAD or more
df[df['price(CAD)']>=100]
# Out:
#       prefix    first         last          email  gender  age  \
# 76      Mrs.  Gregory        Brown     hav@jek.gs  Female   31
# 21093   Mrs.     Cody  Christensen    get@jovu.ag    Male   28
# 24385   Miss   Lizzie        Dixon  goh@tuwjaz.gd  Female   38
#
#                          company              profession           phone  \
# 76           E*Trade Group, Inc.                Novelist  (625) 537-8923
# 21093        National City Corp.  Hospital Administrator  (261) 737-3292
# 24385  FleetBoston Financial Co.    Compensation Analyst  (989) 239-1752
#
#         postal province             cc_no   cc_exp   cc_type  price(CAD)  \
# 76     X3S 4Q2       PE  6010000000000000  04/2018      Visa       100.0
# 21093  X0S 1O5       PE   201000000000000  03/2024       JCB       100.0
# 24385  V8X 9V6       NB  6300000000000000  07/2019  Bankcard       100.0
#
#       fav_color             ip    weekday ampm        date
# 76        Green  212.100.18.95     Monday   am  10/23/2063
# 21093     Green  168.48.19.165  Wednesday   pm  03/28/1955
# 24385      Blue   140.87.99.78   Saturday   pm  03/03/1983

# %% [markdown]
# **13. How many emails are associated with this credit card number '5020000000000230'?**

# %%
# Displaying emails are associated with the credit card number '5020000000000230'
df[df['cc_no']==5020000000000230][['email']]
# Out:
#              email
# 0  sebvajom@kol.km
# 1    acu@jatsot.ug

# %%
df[df['cc_no']==5020000000000230]['email']
# Out:
# 0    sebvajom@kol.km
# 1      acu@jatsot.ug
# Name: email, dtype: object

# %%
df[df['cc_no']==5020000000000230][['email', 'first']]
# Out:
#              email    first
# 0  sebvajom@kol.km      Ray
# 1    acu@jatsot.ug  Claudia

# %%
type(df[df['cc_no']==5020000000000230][['email']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['cc_no']==5020000000000230
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 29995    False
# 29996    False
# 29997    False
# 29998    False
# 29999    False
# Name: cc_no, Length: 30000, dtype: bool

# %% [markdown]
# **14. We need to send new cards to the customers well before the expire, how many cards are expiring in 2019?**<br>
# *Use `sum()` and `count()` and see the difference in their use :)*

# %%
df.head()
# Out:
#   prefix    first       last              email  gender  age  \
# 0    Dr.      Ray     Morton    sebvajom@kol.km    Male   38
# 1   Miss  Claudia  Rodriquez      acu@jatsot.ug  Female   51
# 2   Miss    Harry      Meyer          zuz@lo.wf  Female   51
# 3   Miss    Edith    Gilbert  hansohsi@jupec.md  Female   55
# 4    Dr.     Lura     Murphy     webediti@je.st  Female   20
#
#                         company              profession           phone  \
# 0                Medtronic Inc.        Health Therapist  (987) 619-2695
# 1  Ames Department Stores, Inc.        Health Therapist  (356) 736-7352
# 2                     CSX Corp.     Political Scientist  (539) 246-1806
# 3        Murphy Oil Corporation  Transportation Manager  (984) 962-7494
# 4                  PETsMART Inc            Statistician  (902) 568-9748
#
#     postal province             cc_no   cc_exp                    cc_type  \
# 0  B6V 3W3       MB  5020000000000230  05/2018                       Solo
# 1  G7M 5F3       SK  5020000000000230  07/2028                       Visa
# 2  A0Z 6P9       NS  6300000000000000  02/2023                     Switch
# 3  P9I 9H3       YT  3530000000000000  02/2028                    Maestro
# 4  S1A 6K0       ON  4030000000000000  10/2025  Diners Club International
#
#    price(CAD) fav_color              ip    weekday ampm        date
# 0        8.36      Blue    126.23.139.2     Sunday   pm  04/05/1930
# 1       68.31     Black  106.198.76.211    Tuesday   am  12/20/1926
# 2       34.65     Black  186.150.187.29  Wednesday   pm  08/20/1931
# 3       64.59     White   80.140.57.161   Saturday   am  06/18/2001
# 4       20.83    Yellow   211.103.43.41     Friday   pm  06/14/2045

# %%
# Displaying the number of cards are expiring in 2019
#using count
df[df['cc_exp'].apply(lambda x: x[5:]) == '19']
# Out:
#       prefix     first       last              email  gender  age  \
# 45      Mrs.  Winifred  Henderson     ezamaw@radi.kn  Female   43
# 46      Miss   Carolyn     Horton   dehje@mowakbo.tj    Male   22
# 49      Miss    Virgie      Adams   lodbinogu@ir.edu    Male   56
# 60      Mrs.     Blake       Hart         nup@pov.nc  Female   46
# 66      Miss     Leila  Carpenter       ke@wufiol.wf    Male   21
# ...      ...       ...        ...                ...     ...  ...
# 29952    Mr.     Julia    Elliott  zuruhmu@gevbon.th  Female   18
# 29957   Mrs.    Ronald   Stephens          beg@be.sc  Female   29
# 29959   Mrs.     Isaac   Guerrero        ji@rofom.ve    Male   21
# 29966   Mrs.    Hunter  Rodriguez      zubibil@fo.do  Female   26
# 29987    Mr.     Billy      Lucas     hihdu@kuwze.hm  Female   38
#
#                                 company                          profession  \
# 45                  Western Digital Inc                  Relocation Manager
# 46     Stewart & Stevenson Services Inc                    Employment Agent
# 49                   Maxtor Corporation                  Systems Programmer
# 60              Kindred Healthcare Inc.        Computer Graphics Specialist
# 66                    W.W. Grainger Inc                              Artist
# ...                                 ...                                 ...
# 29952      Gentiva Health Services Inc.               Management Consultant
# 29957            McDonald's Corporation                           Geologist
# 29959             Johnson Controls Inc.                              Lawyer
# 29966                    Pharmacia Corp                  Interior Decorator
# 29987                Deluxe Corporation  Organizational Development Manager
#
#                 phone   postal province             cc_no   cc_exp  \
# 45     (250) 572-7482  K9C 2D2       BC  6300000000000000  12/2019
# 46     (737) 647-5446  L1F 9E3       PE  4900000000000000  07/2019
# 49     (764) 601-4889  B2O 6Z0       NB  3530000000000000  02/2019
# 60     (719) 605-1004  X0O 5E1       PE  5480000000000000  10/2019
# 66     (816) 775-3467  E5X 5V9       NS  5140000000000000  11/2019
# ...               ...      ...      ...               ...      ...
# 29952  (878) 729-1214  C6L 3S8       AB  6010000000000000  05/2019
# 29957  (937) 288-1029  V4W 1T1       YT  5170000000000000  06/2019
# 29959  (706) 297-1902  B9M 1U5       AB  5610000000000000  10/2019
# 29966  (874) 494-4542  K1M 8T0       AB  3530000000000000  09/2019
# 29987  (933) 517-6356  K6I 2U5       QC    36400000000000  03/2019
#
#                          cc_type  price(CAD) fav_color               ip  \
# 45                         Laser       99.49      Blue    196.43.87.187
# 46                  InstaPayment       44.46    Yellow  135.153.126.179
# 49     Diners Club Carte Blanche       66.05       Red  175.149.148.141
# 60                  InstaPayment       89.87     White   164.16.206.229
# 66                 Visa Electron       29.63     Green   99.203.101.232
# ...                          ...         ...       ...              ...
# 29952  Diners Club International       42.49      Blue    42.62.136.183
# 29957              Discover Card       17.32       Red    46.127.70.118
# 29959        Diners Club enRoute       26.69     White   207.217.50.132
# 29966               InstaPayment       62.58     Green   108.20.175.201
# 29987               InstaPayment       21.17      Blue       72.8.98.51
#
#          weekday ampm        date
# 45     Wednesday   pm  07/21/2051
# 46     Wednesday   pm  07/25/2010
# 49        Monday   am  05/15/2047
# 60        Sunday   am  05/05/1942
# 66       Tuesday   am  01/28/1936
# ...          ...  ...         ...
# 29952   Saturday   am  10/17/2063
# 29957     Monday   pm  12/05/1913
# 29959     Monday   pm  01/25/1958
# 29966    Tuesday   am  09/10/1918
# 29987    Tuesday   pm  05/18/1929
#
# [2684 rows x 20 columns]

# %%
# Displaying the number of cards are expiring in 2019
# using sum
sum(df['cc_exp'].apply(lambda x: x[5:]) == '19')
# Out:
# 2684

# %% [markdown]
# **15. How many people use Visa as their Credit Card Provider?**

# %%
# Displaying number of customers who use Visa as their Credit Card Provider
# using count
print(df[df['cc_type']=='Visa'][['prefix']].count())
# using sum
print(f'Visa Credit Card User: {sum(df["cc_type"]=="Visa")}')
# Out:
# prefix    1721
# dtype: int64
# Visa Credit Card User: 1721

# %% [markdown]
# **16. Can you find the customer who spent 100 CAD using Visa?**

# %%
# Displaying the customer who spent 100 CAD using Visa
df[(df['price(CAD)']==100) & (df['cc_type']=='Visa')]
# Out:
#    prefix    first   last       email  gender  age              company  \
# 76   Mrs.  Gregory  Brown  hav@jek.gs  Female   31  E*Trade Group, Inc.
#
#    profession           phone   postal province             cc_no   cc_exp  \
# 76   Novelist  (625) 537-8923  X3S 4Q2       PE  6010000000000000  04/2018
#
#    cc_type  price(CAD) fav_color             ip weekday ampm        date
# 76    Visa       100.0     Green  212.100.18.95  Monday   am  10/23/2063

# %% [markdown]
# **17. What are two most common professions?**

# %%
# Displaying the two most common professions
df['profession'].value_counts().head(2)
# Out:
# profession
# Preschool Teacher       112
# Distribution Manager    107
# Name: count, dtype: int64

# %% [markdown]
# **18. Can you tell the top 5 most popular email providers? (e.g. gmail.com, yahoo.com, etc...)**

# %%
# Displaying top 5 most popular email providers
df['email'].apply(lambda x: x.split('@')[1]).value_counts().head(5)
# Out:
# email
# gmail.com      1687
# me.com         1676
# outlook.com    1664
# live.com       1660
# hotmail.com    1659
# Name: count, dtype: int64

# %% [markdown]
# **19. Is there any customer who is using email with "am.edu"?**<br>
# Hint: Use `lambda` expression in `apply()`. split the email address at `@`.

# %%
# Displaying customer who is using email with "am.edu"
lambda x: 'am.edu' in x.split('@')[1]
df[df['email'].apply(lambda x: 'am.edu' in x.split('@')[1])]
# Out:
#     prefix    first      last         email  gender  age  \
# 150   Miss  Loretta  Fletcher  barit@am.edu  Female   48
#
#                      company                profession           phone  \
# 150  York International Corp  Rehabilitation Counselor  (323) 279-8038
#
#       postal province             cc_no   cc_exp  \
# 150  E5X 8L0       QC  6330000000000000  05/2021
#
#                                 cc_type  price(CAD) fav_color              ip  \
# 150  Diners Club United States & Canada       97.26     White  147.57.240.225
#
#     weekday ampm        date
# 150  Monday   am  11/07/2066

# %% [markdown]
# **20. Which day of the week, the store gets more customers?**

# %%
df['weekday'].value_counts().head()
# Out:
# weekday
# Saturday     4376
# Wednesday    4365
# Thursday     4327
# Friday       4316
# Monday       4216
# Name: count, dtype: int64

# %%
# Dispalying the day of the week, the store gets more customers
df['weekday'].value_counts().head(1)
# Out:
# weekday
# Saturday    4376
# Name: count, dtype: int64

# %% [markdown]
# # Excellent work!
